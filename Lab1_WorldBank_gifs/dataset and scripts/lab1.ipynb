# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_85.csv')
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %%
sortedDf= df.sort_values(by="2022", ascending=False)
sortedDf.head(50)
# Out:
#                                           Country Name Country Code  \
# 259                                              World          WLD
# 103                                   IDA & IBRD total          IBT
# 140                                Low & middle income          LMY
# 156                                      Middle income          MIC
# 102                                          IBRD only          IBD
# 62                          Early-demographic dividend          EAR
# 139                                Lower middle income          LMC
# 249                                Upper middle income          UMC
# 63                                 East Asia & Pacific          EAS
# 142                          Late-demographic dividend          LTE
# 61         East Asia & Pacific (excluding high income)          EAP
# 230         East Asia & Pacific (IDA & IBRD countries)          TEA
# 204                                         South Asia          SAS
# ...

# %%
dfIndia=df.iloc[109,-63:-1]
dfChina=df.iloc[40,-63:-1]
dfIndonesia=df.iloc[106,-63:-1]
dfPakistan=df.iloc[184,-63:-1]
dfNigeria=df.iloc[174,-63:-1]
dfForPlot=pd.concat([dfIndia, dfChina, dfIndonesia, dfPakistan, dfNigeria], axis=1)
dfForPlot.columns=["India","China","Indonesia","Pakistan","Nigeria"]

dfForPlot.head()
# Out:
#             India        China   Indonesia    Pakistan     Nigeria
# 1960  445954579.0  667070000.0  88382881.0  45954226.0  44928342.0
# 1961  456351876.0  660330000.0  90816938.0  47060915.0  45855507.0
# 1962  467024193.0  665770000.0  93345489.0  48161841.0  46821845.0
# 1963  477933619.0  682335000.0  95962527.0  49325050.0  47822569.0
# 1964  489059309.0  698355000.0  98675061.0  50552592.0  48856332.0

# %%
dfForPlot.tail()
# Out:
#              India         China    Indonesia     Pakistan      Nigeria
# 2017  1354195680.0  1396215000.0  264498852.0  216379655.0  193495907.0
# 2018  1369003306.0  1402760000.0  267066843.0  219731479.0  198387623.0
# 2019  1383112050.0  1407745000.0  269582878.0  223293280.0  203304492.0
# 2020  1396387127.0  1411100000.0  271857970.0  227196741.0  208327405.0
# 2021  1407563842.0  1412360000.0  273753191.0  231402117.0  213401323.0

# %%
#Test matplotlib
x = np.linspace(0, 10, 100)  # 100 points beetwen 0 and 10
y = x ** 2  
plt.plot(x, y)

plt.title("y = x^2")
plt.xlabel("x")
plt.ylabel("y")

plt.show()
plt.savefig("test.png")

# %%
#One plot
row = dfForPlot.iloc[0]

plt.figure(figsize=(10,6))
row.plot(kind="bar")

plt.xticks(ticks=range(len(row.index)), labels=row.index)

plt.title('Comparison of the populations of the largest countries')
plt.xlabel('Country')
plt.ylabel('Population')

plt.show()

#Second plot
row = dfForPlot.iloc[50]

plt.figure(figsize=(10,6))
row.plot(kind="bar")

plt.xticks(ticks=range(len(row.index)), labels=row.index)

plt.title('Comparison of the populations of the largest countries')
plt.xlabel('Country')
plt.ylabel('Population')

plt.show()

# %%
#Generate all plots for gif

for index, row in dfForPlot.iterrows():
    plt.figure(figsize=(10,6))
    row.plot(kind="bar")
    
    plt.xticks(ticks=range(len(row.index)), labels=row.index)

    title= "Comparison of the populations of the largest countries " + str(index)
    plt.title(title)
    plt.xlabel('Country')
    plt.ylabel('Population')
    
    filename="plots/plot"+str(index)+".png"
    plt.savefig(filename)
    plt.close()

# %%
#Function for generating plots
def plotGenerator(dfForPlot):
    for index, row in dfForPlot.iterrows():
        plt.figure(figsize=(10,6))
        row.plot(kind="bar")

        plt.xticks(ticks=range(len(row.index)), labels=row.index)

        title= "Comparison of the populations of the largest countries " + str(index)
        plt.title(title)
        plt.xlabel('Country')
        plt.ylabel('Population')

        filename="plots/plot"+str(index)+".png"
        plt.savefig(filename)
        plt.close()

# %% [markdown]
# # Second gif

# %%
df2=sortedDf.iloc[50:55,-63:-1]
df2=df2.T
df2.tail()
# Out:
#               20           202          154          119          72
# 2017  161793964.0  144496739.0  122839258.0  126972000.0  108197950.0
# 2018  163683958.0  144477859.0  124013861.0  126811000.0  111129438.0
# 2019  165516222.0  144406261.0  125085311.0  126633000.0  114120594.0
# 2020  167420951.0  144073139.0  125998302.0  126261000.0  117190911.0
# 2021  169356251.0  144130482.0  126705138.0  125681593.0  120283026.0

# %%
newColNames=sortedDf.iloc[50:55,0]
df2.columns=newColNames.values
df2.tail()
# Out:
#        Bangladesh  Russian Federation       Mexico        Japan     Ethiopia
# 2017  161793964.0         144496739.0  122839258.0  126972000.0  108197950.0
# 2018  163683958.0         144477859.0  124013861.0  126811000.0  111129438.0
# 2019  165516222.0         144406261.0  125085311.0  126633000.0  114120594.0
# 2020  167420951.0         144073139.0  125998302.0  126261000.0  117190911.0
# 2021  169356251.0         144130482.0  126705138.0  125681593.0  120283026.0

# %%
#Generate all plots for gif
plotGenerator(df2)

# %% [markdown]
# # Gif 3

# %%
df3=sortedDf.loc[df.iloc[:,0]=="Poland"]
df3.head()
# Out:
#     Country Name Country Code     Indicator Name Indicator Code        1960  \
# 190       Poland          POL  Population, total    SP.POP.TOTL  29637450.0
#
#            1961        1962        1963        1964        1965  ...  \
# 190  29964000.0  30308500.0  30712000.0  31139450.0  31444950.0  ...
#
#            2013        2014        2015        2016        2017        2018  \
# 190  38040196.0  38011735.0  37986412.0  37970087.0  37974826.0  37974750.0
#
#            2019        2020        2021        2022
# 190  37965475.0  37899070.0  37747124.0  36821749.0
#
# [1 rows x 67 columns]

# %%
indexOfPoland = int(np.where(sortedDf.iloc[:,0] == 'Poland')[0])
print(indexOfPoland)

df3=sortedDf.iloc[(indexOfPoland-2):(indexOfPoland+3),-63:-1]
df3.tail()
# Out:
# 84
#            1960        1961        1962        1963        1964        1965  \
# 248  42767251.0  43365219.0  43924755.0  44445903.0  44941406.0  45387091.0
# 148  11769774.0  12081713.0  12404757.0  12726686.0  13044254.0  13381880.0
# 190  29637450.0  29964000.0  30308500.0  30712000.0  31139450.0  31444950.0
# 205   4165563.0   4306048.0   4458516.0   4621655.0   4795130.0   4978922.0
# 252   8372311.0   8692048.0   9038222.0   9394588.0   9758147.0  10130096.0
#
#            1966        1967        1968        1969  ...        2012  \
# 248  45809120.0  46235370.0  46635196.0  46990889.0  ...  45593342.0
# 148  13738502.0  14109755.0  14490077.0  14876982.0  ...  33352169.0
# 190  31681000.0  31987155.0  32294655.0  32548300.0  ...  38063164.0
# 205   5173237.0   5381026.0   5604582.0   5844843.0  ...  30821543.0
# 252  10504969.0  10881533.0  11261600.0  11641640.0  ...  29774500.0
#
#            2013        2014        2015        2016        2017        2018  \
# ...

# %%
df3=df3.T
df3.tail()
# Out:
#              248         148         190         205         252
# 2017  44831135.0  35528115.0  37974826.0  34193122.0  32388600.0
# 2018  44622518.0  35927511.0  37974750.0  35018133.0  32956100.0
# 2019  44386203.0  36304408.0  37965475.0  35827362.0  33580350.0
# 2020  44132049.0  36688772.0  37899070.0  35997107.0  34232050.0
# 2021  43822901.0  37076584.0  37747124.0  35950396.0  34915100.0

# %%
newColNames=sortedDf.iloc[(indexOfPoland-2):(indexOfPoland+3),0]
df3.columns=newColNames.values
df3.tail()
# Out:
#          Ukraine     Morocco      Poland  Saudi Arabia  Uzbekistan
# 2017  44831135.0  35528115.0  37974826.0    34193122.0  32388600.0
# 2018  44622518.0  35927511.0  37974750.0    35018133.0  32956100.0
# 2019  44386203.0  36304408.0  37965475.0    35827362.0  33580350.0
# 2020  44132049.0  36688772.0  37899070.0    35997107.0  34232050.0
# 2021  43822901.0  37076584.0  37747124.0    35950396.0  34915100.0

# %%
plotGenerator(df3)
