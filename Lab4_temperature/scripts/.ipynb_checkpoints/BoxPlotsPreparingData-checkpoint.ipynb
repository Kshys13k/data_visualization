# %%
import pandas as pd

# %%
df=pd.read_csv("../data/cleaned_temperature.csv")
df
# Out:
#        Unnamed: 0  month  year      City country_id      Country Latitude  \
# 0               0      6  1853  Auckland        NEW  New Zealand   36.17S
# 1               1      7  1853  Auckland        NEW  New Zealand   36.17S
# 2               2      8  1853  Auckland        NEW  New Zealand   36.17S
# 3               3      9  1853  Auckland        NEW  New Zealand   36.17S
# 4               4     10  1853  Auckland        NEW  New Zealand   36.17S
# ...           ...    ...   ...       ...        ...          ...      ...
# 47063       47063      4  2013   Wroclaw        POL       Poland   50.63N
# 47064       47064      5  2013   Wroclaw        POL       Poland   50.63N
# 47065       47065      6  2013   Wroclaw        POL       Poland   50.63N
# 47066       47066      7  2013   Wroclaw        POL       Poland   50.63N
# 47067       47067      8  2013   Wroclaw        POL       Poland   50.63N
#
#       Longitude  AverageTemperatureCel  AverageTemperatureUncertaintyCel
# ...

# %%
dfPol=df[df["country_id"]=="POL"]
dfPol
# Out:
#        Unnamed: 0  month  year     City country_id Country Latitude Longitude  \
# 40803       40803     11  1743   Warsaw        POL  Poland   52.24N    21.02E
# 40804       40804      4  1744   Warsaw        POL  Poland   52.24N    21.02E
# 40805       40805      5  1744   Warsaw        POL  Poland   52.24N    21.02E
# 40806       40806      6  1744   Warsaw        POL  Poland   52.24N    21.02E
# 40807       40807      9  1744   Warsaw        POL  Poland   52.24N    21.02E
# ...           ...    ...   ...      ...        ...     ...      ...       ...
# 47063       47063      4  2013  Wroclaw        POL  Poland   50.63N    16.48E
# 47064       47064      5  2013  Wroclaw        POL  Poland   50.63N    16.48E
# 47065       47065      6  2013  Wroclaw        POL  Poland   50.63N    16.48E
# 47066       47066      7  2013  Wroclaw        POL  Poland   50.63N    16.48E
# 47067       47067      8  2013  Wroclaw        POL  Poland   50.63N    16.48E
#
# ...

# %%
print(df["country_id"].unique())
# Out:
# ['NEW' 'BRA' 'SOU' 'UKR' 'FRA' 'SWE' 'JAP' 'POL']
